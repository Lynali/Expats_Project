# %%
import numpy as np

# Labor Migrant United States Females Data
data = [24992.1914, 24269.6016, 23450.1602, 23161.7148, 23356.3184]

# Mean
mean = np.mean(data)
print(f"Mean: {mean}")

#Median
median = np.median(data)
print(f"Median: {median}")

#Standard Deviation
std_dev = np.std(data)
print(f"Standard Deviation: {std_dev}")
# Out:
# Mean: 23845.997280000003
# Median: 23450.1602
# Standard Deviation: 686.7192282878306

# %%
# Labor Migrant United States Males Data
data = [23960.6406, 23080.7168, 21956.5449, 21575.1543, 21942.5352]

# Mean
mean = np.mean(data)
print(f"Mean: {mean}")

#Median
median = np.median(data)
print(f"Median: {median}")

#Standard Deviation
std_dev = np.std(data)
print(f"Standard Deviation: {std_dev}")
# Out:
# Mean: 22503.118359999997
# Median: 21956.5449
# Standard Deviation: 886.8037394022074

# %%
# Labor Migrant European Countries Females Data
data = [29440.5658, 28141.7329, 29140.7203, 30337.5490, 32343.4185]

# Mean
mean = np.mean(data)
print(f"Mean: {mean}")

#Median
median = np.median(data)
print(f"Median: {median}")

#Standard Deviation
std_dev = np.std(data)
print(f"Standard Deviation: {std_dev}")
# Out:
# Mean: 29880.7973
# Median: 29440.5658
# Standard Deviation: 1416.9677495984824

# %%
# Labor Migrant European Countries males Data
data = [26973.8623, 25475.6048, 26706.8129, 27657.1191, 29113.5730]

# Mean
mean = np.mean(data)
print(f"Mean: {mean}")

#Median
median = np.median(data)
print(f"Median: {median}")

#Standard Deviation
std_dev = np.std(data)
print(f"Standard Deviation: {std_dev}")
# Out:
# Mean: 27185.394419999997
# Median: 26973.8623
# Standard Deviation: 1194.7856262802013

# %%
import numpy as np
import matplotlib.pyplot as plt

mean = 23845.9972
std_dev = 686.7192
sample_size = 5

data = np.random.normal(loc=mean, scale=std_dev, size=sample_size)

plt.hist(data, bins=3, density=True, alpha=0.6, color='b', edgecolor='black')

plt.axvline(mean, color='red', linestyle='dashed', linewidth=2, label=f'Mean: {mean:.2f}')

x = np.linspace(mean - 4*std_dev, mean + 4*std_dev, 100)
pdf = (1 / (std_dev * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x - mean) / std_dev) ** 2)

plt.plot(x, pdf, 'r', linewidth=2)

plt.title('Bell Curve (Normal Distribution) with Sample Size 5 (US Females)')
plt.xlabel('Value')
plt.ylabel('Density')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

mean = 22503.1183
std_dev = 886.8037
sample_size = 5

data = np.random.normal(loc=mean, scale=std_dev, size=sample_size)

plt.hist(data, bins=3, density=True, alpha=0.6, color='b', edgecolor='black')

plt.axvline(mean, color='red', linestyle='dashed', linewidth=2, label=f'Mean: {mean:.2f}')

x = np.linspace(mean - 4*std_dev, mean + 4*std_dev, 100)
pdf = (1 / (std_dev * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x - mean) / std_dev) ** 2)

plt.plot(x, pdf, 'r', linewidth=2)

plt.title('Bell Curve (Normal Distribution) with Sample Size 5 (US Males)')
plt.xlabel('Value')
plt.ylabel('Density')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

mean = 29880.7973
std_dev = 1416.9677
sample_size = 5

data = np.random.normal(loc=mean, scale=std_dev, size=sample_size)

plt.hist(data, bins=3, density=True, alpha=0.6, color='b', edgecolor='black')

plt.axvline(mean, color='red', linestyle='dashed', linewidth=2, label=f'Mean: {mean:.2f}')

x = np.linspace(mean - 4*std_dev, mean + 4*std_dev, 100)
pdf = (1 / (std_dev * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x - mean) / std_dev) ** 2)

plt.plot(x, pdf, 'r', linewidth=2)

plt.title('Bell Curve (Normal Distribution) with Sample Size 5 (European Countries Females)')
plt.xlabel('Value')
plt.ylabel('Density')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

mean = 27185.3944
std_dev = 1194.7856
sample_size = 5

data = np.random.normal(loc=mean, scale=std_dev, size=sample_size)

plt.hist(data, bins=3, density=True, alpha=0.6, color='b', edgecolor='black')

plt.axvline(mean, color='red', linestyle='dashed', linewidth=2, label=f'Mean: {mean:.2f}')

x = np.linspace(mean - 4*std_dev, mean + 4*std_dev, 100)
pdf = (1 / (std_dev * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x - mean) / std_dev) ** 2)

plt.plot(x, pdf, 'r', linewidth=2)

plt.title('Bell Curve (Normal Distribution) with Sample Size 5 (European Countries Males)')
plt.xlabel('Value')
plt.ylabel('Density')

plt.show()
